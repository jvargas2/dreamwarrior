# %%
import random

class Env:
    state = [2, 0]
    rewards = [[1, -1, -1], [-1, -10, -1], [-1, -1, 10]]
    q_values = []
    epsilon = 1.0
    episode = 0
    learning_rate = 0.7
    gamma = 0.99
    
    def __init__(self):
        q_values = []
        
        for i in range(9):
            row = []
            for j in range(4):
                row.append(0)
            q_values.append(row)
            
        self.q_values = q_values
        
    def get_position(self, state):
        return state[0] * 3 + state[1]
        
    def select_action(self):
        action = None
        sample = random.random()
        epsilon_threshold = self.epsilon - (self.episode * 0.1)
        
        print('Epsilon Threshold: %f' % epsilon_threshold)
        print('Random Sample: %f' % sample)
        
        if sample > epsilon_threshold:
            print('EXPLOITATION')
            position = self.get_position(self.state)
            row = self.q_values[position]
            action = row.index(max(row))
        else:
            print('EXPLORATION')
            action = random.randrange(4)
            
        return action

    def step(self, action):
        state = self.state.copy()
        next_state = self.state
        
        # Calculate next state
        if action == 0:
            # Move left
            next_state[1] -= 1
        elif action == 1:
            # Move right
            next_state[1] += 1
        elif action == 2:
            # Move up
            next_state[0] -= 1
        elif action == 3:
            # Move down
            next_state[0] += 1
        else:
            raise ValueError('Invalid action')
        
        for i in range(2):
            if next_state[i] < 0:
                next_state[i] = 0
            elif next_state[i] > 2:
                next_state[i] = 2
                
        reward = self.rewards[next_state[0]][next_state[1]]
        done = False
        
        position = self.get_position(state)
        next_position = self.get_position(next_state)
        
        old_q = self.q_values[position][action]
        next_q = max(self.q_values[next_position])
        
        a = self.learning_rate
        
        new_q = ((1 - a) * old_q) + (a * (reward + self.gamma * next_q))
        self.q_values[position][action] = new_q
        
        print('Old Q-Value: %.2f' % old_q)
        print('Next Q-Value: %.2f' % next_q)
        print('(1 - a)old_q + a(r + g(next_q)))')
        print('(%.2f)(%.2f) + %.2f(%.2f + %.2f(%.2f))' % (1 - a, old_q, a, reward, self.gamma, next_q))
        print('%.2f + %.2f(%.2f)' % (((1-a) * old_q), a, (reward + self.gamma * next_q)))
        print('%.2f' % new_q)
        
        if next_state == [1, 1] or next_state == [2, 2]:
            done = True
        
        self.print_state()
        self.print_q_table()
        
        return state, reward, done
    
    def reset(self):
        self.state = [2, 0]
        self.episode += 1
    
    def print_state(self):        
        rows = [
            '|C| | |',
            '| |B| |',
            '| | |W|'
        ]

        row = list(rows[self.state[0]])
        row[self.state[1] * 2 + 1] = 'L'
        rows[self.state[0]] = ''.join(row)
        
        print('\nSTATE:')
        print(rows[0])
        print(rows[1])
        print(rows[2])
        
    def print_q_table(self):
        positions = ['C', 1, 2, 3, 'B', 4, 5, 6, 'W']
        
        print('\nQ Table:\n   [L, R, U, D]')

        for position, row in zip(positions, self.q_values):
            print('%s: [%.2f, %.2f, %.2f, %.2f]' % (position, row[0], row[1], row[2], row[3]))
        
    
action_name = ['Left', 'Right', 'Up', 'Down']
env = Env()
env.print_state()
done = False
max_episodes = 11

rewards = []

for i in range(max_episodes):
    print('\n=============')
    print('EPISODE %d' % i)
    print('==============')
    
    total_reward = 0
    
    while not done:
        print('\n---------------')
        action = env.select_action()
        print('Action Selected: %s' % action_name[action])
        _, reward, done = env.step(action)
        total_reward += reward
        print('\nReward: %d' % reward)
        print('Done: %s' % done)

    rewards.append(total_reward)
    env.reset()
    done = False
    
print('\n===========')
print('FINAL STATS')
print('Rewards: %s' % rewards)
# Out:
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# =============
# EPISODE 0
# ==============
#
# ---------------
# Epsilon Threshold: 1.000000
# Random Sample: 0.573923
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, 0.00, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [0.00, 0.00, -0.70, 0.00]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 1.000000
# Random Sample: 0.564576
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-10.00 + 0.99(0.00))
# 0.00 + 0.70(-10.00)
# -7.00
#
# STATE:
# |C| | |
# | |L| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -7.00, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [0.00, 0.00, -0.70, 0.00]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -10
# Done: True
#
# =============
# EPISODE 1
# ==============
#
# ---------------
# Epsilon Threshold: 0.900000
# Random Sample: 0.198385
# EXPLORATION
# Action Selected: Up
# Old Q-Value: -0.70
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.70) + 0.70(-1.00 + 0.99(0.00))
# -0.21 + 0.70(-1.00)
# -0.91
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -7.00, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [0.00, 0.00, -0.91, 0.00]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.900000
# Random Sample: 0.636798
# EXPLORATION
# Action Selected: Right
# Old Q-Value: -7.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-7.00) + 0.70(-10.00 + 0.99(0.00))
# -2.10 + 0.70(-10.00)
# -9.10
#
# STATE:
# |C| | |
# | |L| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [0.00, 0.00, -0.91, 0.00]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -10
# Done: True
#
# =============
# EPISODE 2
# ==============
#
# ---------------
# Epsilon Threshold: 0.800000
# Random Sample: 0.910575
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.70, 0.00, -0.91, 0.00]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.800000
# Random Sample: 0.552694
# EXPLORATION
# Action Selected: Down
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.70, 0.00, -0.91, -0.70]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.800000
# Random Sample: 0.610261
# EXPLORATION
# Action Selected: Left
# Old Q-Value: -0.70
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.70) + 0.70(-1.00 + 0.99(0.00))
# -0.21 + 0.70(-1.00)
# -0.91
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, 0.00, -0.91, -0.70]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.800000
# Random Sample: 0.703814
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.70, -0.91, -0.70]
# 6: [0.00, 0.00, 0.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.800000
# Random Sample: 0.675629
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-10.00 + 0.99(0.00))
# 0.00 + 0.70(-10.00)
# -7.00
#
# STATE:
# |C| | |
# | |L| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.70, -0.91, -0.70]
# 6: [0.00, 0.00, -7.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -10
# Done: True
#
# =============
# EPISODE 3
# ==============
#
# ---------------
# Epsilon Threshold: 0.700000
# Random Sample: 0.794678
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: -0.70
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.70) + 0.70(-1.00 + 0.99(0.00))
# -0.21 + 0.70(-1.00)
# -0.91
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.91, -0.91, -0.70]
# 6: [0.00, 0.00, -7.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.700000
# Random Sample: 0.557868
# EXPLORATION
# Action Selected: Left
# Old Q-Value: 0.00
# Next Q-Value: -0.70
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(-0.70))
# 0.00 + 0.70(-1.69)
# -1.19
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.91, -0.91, -0.70]
# 6: [-1.19, 0.00, -7.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.700000
# Random Sample: 0.199710
# EXPLORATION
# Action Selected: Up
# Old Q-Value: -0.91
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.91) + 0.70(-1.00 + 0.99(0.00))
# -0.27 + 0.70(-1.00)
# -0.97
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.10, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.91, -0.97, -0.70]
# 6: [-1.19, 0.00, -7.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.700000
# Random Sample: 0.049112
# EXPLORATION
# Action Selected: Right
# Old Q-Value: -9.10
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-9.10) + 0.70(-10.00 + 0.99(0.00))
# -2.73 + 0.70(-10.00)
# -9.73
#
# STATE:
# |C| | |
# | |L| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.91, -0.97, -0.70]
# 6: [-1.19, 0.00, -7.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -10
# Done: True
#
# =============
# EPISODE 4
# ==============
#
# ---------------
# Epsilon Threshold: 0.600000
# Random Sample: 0.547456
# EXPLORATION
# Action Selected: Right
# Old Q-Value: -0.91
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.91) + 0.70(-1.00 + 0.99(0.00))
# -0.27 + 0.70(-1.00)
# -0.97
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.97, -0.97, -0.70]
# 6: [-1.19, 0.00, -7.00, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.600000
# Random Sample: 0.472786
# EXPLORATION
# Action Selected: Up
# Old Q-Value: -7.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-7.00) + 0.70(-10.00 + 0.99(0.00))
# -2.10 + 0.70(-10.00)
# -9.10
#
# STATE:
# |C| | |
# | |L| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.97, -0.97, -0.70]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -10
# Done: True
#
# =============
# EPISODE 5
# ==============
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.803465
# EXPLOITATION
# Action Selected: Down
# Old Q-Value: -0.70
# Next Q-Value: -0.70
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.70) + 0.70(-1.00 + 0.99(-0.70))
# -0.21 + 0.70(-1.69)
# -1.40
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.97, -0.97, -1.40]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.143094
# EXPLORATION
# Action Selected: Down
# Old Q-Value: -1.40
# Next Q-Value: -0.91
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-1.40) + 0.70(-1.00 + 0.99(-0.91))
# -0.42 + 0.70(-1.90)
# -1.75
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-0.91, -0.97, -0.97, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.043208
# EXPLORATION
# Action Selected: Left
# Old Q-Value: -0.91
# Next Q-Value: -0.91
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.91) + 0.70(-1.00 + 0.99(-0.91))
# -0.27 + 0.70(-1.90)
# -1.60
#
# STATE:
# |C| | |
# | |B| |
# |L| |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.97, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.110516
# EXPLORATION
# Action Selected: Up
# Old Q-Value: -0.97
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.97) + 0.70(-1.00 + 0.99(0.00))
# -0.29 + 0.70(-1.00)
# -0.99
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [0.00, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.570799
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.00, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.557644
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(1.00 + 0.99(0.00))
# 0.00 + 0.70(1.00)
# 0.70
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.00, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.506249
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(1.00 + 0.99(0.00))
# 0.00 + 0.70(1.00)
# 0.70
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.00, 0.00, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.367131
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 0.00
# Next Q-Value: 0.70
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(1.00 + 0.99(0.70))
# 0.00 + 0.70(1.69)
# 1.19
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.00, 1.19, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.522765
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 1.19
# Next Q-Value: 1.19
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(1.19) + 0.70(1.00 + 0.99(1.19))
# 0.36 + 0.70(2.17)
# 1.88
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.00, 1.88, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.516980
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 1.88
# Next Q-Value: 1.88
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(1.88) + 0.70(1.00 + 0.99(1.88))
# 0.56 + 0.70(2.86)
# 2.56
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.00, 2.56, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.404836
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, -0.70, 2.56, 0.00]
# 1: [0.00, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.532392
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 0.00
# Next Q-Value: 2.56
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(1.00 + 0.99(2.56))
# 0.00 + 0.70(3.54)
# 2.48
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, -0.70, 2.56, 0.00]
# 1: [2.48, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.204263
# EXPLORATION
# Action Selected: Right
# Old Q-Value: -0.70
# Next Q-Value: 2.48
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.70) + 0.70(-1.00 + 0.99(2.48))
# -0.21 + 0.70(1.45)
# 0.81
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.81, 2.56, 0.00]
# 1: [2.48, 0.00, 0.00, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.438914
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 0.00
# Next Q-Value: 2.48
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(2.48))
# 0.00 + 0.70(1.45)
# 1.02
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.81, 2.56, 0.00]
# 1: [2.48, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.206862
# EXPLORATION
# Action Selected: Left
# Old Q-Value: 2.48
# Next Q-Value: 2.56
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(2.48) + 0.70(1.00 + 0.99(2.56))
# 0.74 + 0.70(3.54)
# 3.22
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.81, 2.56, 0.00]
# 1: [3.22, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.685654
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 2.56
# Next Q-Value: 2.56
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(2.56) + 0.70(1.00 + 0.99(2.56))
# 0.77 + 0.70(3.54)
# 3.25
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 0.81, 3.25, 0.00]
# 1: [3.22, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.339617
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 0.81
# Next Q-Value: 3.22
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.81) + 0.70(-1.00 + 0.99(3.22))
# 0.24 + 0.70(2.19)
# 1.77
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 1.77, 3.25, 0.00]
# 1: [3.22, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.910487
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 3.22
# Next Q-Value: 3.25
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(3.22) + 0.70(1.00 + 0.99(3.25))
# 0.97 + 0.70(4.21)
# 3.92
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 1.77, 3.25, 0.00]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.749916
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 3.25
# Next Q-Value: 3.25
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(3.25) + 0.70(1.00 + 0.99(3.25))
# 0.97 + 0.70(4.21)
# 3.92
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 1.77, 3.92, 0.00]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.741107
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 3.92
# Next Q-Value: 3.92
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(3.92) + 0.70(1.00 + 0.99(3.92))
# 1.18 + 0.70(4.88)
# 4.60
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [0.70, 1.77, 4.60, 0.00]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.132274
# EXPLORATION
# Action Selected: Left
# Old Q-Value: 0.70
# Next Q-Value: 4.60
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.70) + 0.70(1.00 + 0.99(4.60))
# 0.21 + 0.70(5.55)
# 4.09
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 4.60, 0.00]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.770130
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 4.60
# Next Q-Value: 4.60
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(4.60) + 0.70(1.00 + 0.99(4.60))
# 1.38 + 0.70(5.55)
# 5.26
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 5.26, 0.00]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.454342
# EXPLORATION
# Action Selected: Down
# Old Q-Value: 0.00
# Next Q-Value: 0.70
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.70))
# 0.00 + 0.70(-0.31)
# -0.21
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 5.26, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 0.70, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.697629
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 0.70
# Next Q-Value: 5.26
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.70) + 0.70(1.00 + 0.99(5.26))
# 0.21 + 0.70(6.21)
# 4.56
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 5.26, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.968051
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 5.26
# Next Q-Value: 5.26
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(5.26) + 0.70(1.00 + 0.99(5.26))
# 1.58 + 0.70(6.21)
# 5.93
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 5.93, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.834985
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 5.93
# Next Q-Value: 5.93
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(5.93) + 0.70(1.00 + 0.99(5.93))
# 1.78 + 0.70(6.87)
# 6.59
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 6.59, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.923585
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 6.59
# Next Q-Value: 6.59
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(6.59) + 0.70(1.00 + 0.99(6.59))
# 1.98 + 0.70(7.52)
# 7.24
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 7.24, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.793594
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 7.24
# Next Q-Value: 7.24
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(7.24) + 0.70(1.00 + 0.99(7.24))
# 2.17 + 0.70(8.17)
# 7.89
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 7.89, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.819089
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 7.89
# Next Q-Value: 7.89
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(7.89) + 0.70(1.00 + 0.99(7.89))
# 2.37 + 0.70(8.81)
# 8.53
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 8.53, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.798986
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 8.53
# Next Q-Value: 8.53
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(8.53) + 0.70(1.00 + 0.99(8.53))
# 2.56 + 0.70(9.45)
# 9.17
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 9.17, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.787976
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 9.17
# Next Q-Value: 9.17
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(9.17) + 0.70(1.00 + 0.99(9.17))
# 2.75 + 0.70(10.08)
# 9.81
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 9.81, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.506424
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 9.81
# Next Q-Value: 9.81
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(9.81) + 0.70(1.00 + 0.99(9.81))
# 2.94 + 0.70(10.71)
# 10.44
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 1.77, 10.44, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.234125
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 1.77
# Next Q-Value: 3.92
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(1.77) + 0.70(-1.00 + 0.99(3.92))
# 0.53 + 0.70(2.88)
# 2.55
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 10.44, -0.21]
# 1: [3.92, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.533731
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 3.92
# Next Q-Value: 10.44
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(3.92) + 0.70(1.00 + 0.99(10.44))
# 1.17 + 0.70(11.34)
# 9.11
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 10.44, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.794335
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 10.44
# Next Q-Value: 10.44
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(10.44) + 0.70(1.00 + 0.99(10.44))
# 3.13 + 0.70(11.34)
# 11.07
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 11.07, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.996825
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 11.07
# Next Q-Value: 11.07
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(11.07) + 0.70(1.00 + 0.99(11.07))
# 3.32 + 0.70(11.96)
# 11.69
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 11.69, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.647516
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 11.69
# Next Q-Value: 11.69
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(11.69) + 0.70(1.00 + 0.99(11.69))
# 3.51 + 0.70(12.57)
# 12.31
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 12.31, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.580386
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 12.31
# Next Q-Value: 12.31
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(12.31) + 0.70(1.00 + 0.99(12.31))
# 3.69 + 0.70(13.18)
# 12.92
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 12.92, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.737899
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 12.92
# Next Q-Value: 12.92
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(12.92) + 0.70(1.00 + 0.99(12.92))
# 3.88 + 0.70(13.79)
# 13.53
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 2.55, 13.53, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.416898
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 2.55
# Next Q-Value: 9.11
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(2.55) + 0.70(-1.00 + 0.99(9.11))
# 0.76 + 0.70(8.02)
# 6.38
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, -0.21]
# 1: [9.11, 0.00, 1.02, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.391169
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 1.02
# Next Q-Value: 9.11
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(1.02) + 0.70(-1.00 + 0.99(9.11))
# 0.30 + 0.70(8.02)
# 5.92
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, -0.21]
# 1: [9.11, 0.00, 5.92, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.023342
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(0.00))
# 0.00 + 0.70(-1.00)
# -0.70
#
# STATE:
# |C| |L|
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, -0.21]
# 1: [9.11, -0.70, 5.92, 0.00]
# 2: [0.00, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.389049
# EXPLORATION
# Action Selected: Left
# Old Q-Value: 0.00
# Next Q-Value: 9.11
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-1.00 + 0.99(9.11))
# 0.00 + 0.70(8.02)
# 5.61
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, -0.21]
# 1: [9.11, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.534235
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 9.11
# Next Q-Value: 13.53
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(9.11) + 0.70(1.00 + 0.99(13.53))
# 2.73 + 0.70(14.40)
# 12.81
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, -0.21]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.062112
# EXPLORATION
# Action Selected: Down
# Old Q-Value: -0.21
# Next Q-Value: 4.56
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.21) + 0.70(-1.00 + 0.99(4.56))
# -0.06 + 0.70(3.51)
# 2.39
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, 2.39]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [-0.70, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.222562
# EXPLORATION
# Action Selected: Left
# Old Q-Value: -0.70
# Next Q-Value: 4.56
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.70) + 0.70(-1.00 + 0.99(4.56))
# -0.21 + 0.70(3.51)
# 2.25
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, 2.39]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 4.56, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.062096
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 4.56
# Next Q-Value: 13.53
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(4.56) + 0.70(1.00 + 0.99(13.53))
# 1.37 + 0.70(14.40)
# 11.44
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, 2.39]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 11.44, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.289333
# EXPLORATION
# Action Selected: Down
# Old Q-Value: 2.39
# Next Q-Value: 11.44
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(2.39) + 0.70(-1.00 + 0.99(11.44))
# 0.72 + 0.70(10.33)
# 7.95
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, 7.95]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 11.44, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.677525
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 11.44
# Next Q-Value: 13.53
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(11.44) + 0.70(1.00 + 0.99(13.53))
# 3.43 + 0.70(14.40)
# 13.51
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 13.53, 7.95]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.039645
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 13.53
# Next Q-Value: 13.53
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(13.53) + 0.70(1.00 + 0.99(13.53))
# 4.06 + 0.70(14.40)
# 14.14
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 6.38, 14.14, 7.95]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.067727
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 6.38
# Next Q-Value: 12.81
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(6.38) + 0.70(-1.00 + 0.99(12.81))
# 1.91 + 0.70(11.68)
# 10.09
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 14.14, 7.95]
# 1: [12.81, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.803504
# EXPLOITATION
# Action Selected: Left
# Old Q-Value: 12.81
# Next Q-Value: 14.14
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(12.81) + 0.70(1.00 + 0.99(14.14))
# 3.84 + 0.70(15.00)
# 14.34
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 14.14, 7.95]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.937825
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 14.14
# Next Q-Value: 14.14
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(14.14) + 0.70(1.00 + 0.99(14.14))
# 4.24 + 0.70(15.00)
# 14.74
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 14.74, 7.95]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.971089
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 14.74
# Next Q-Value: 14.74
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(14.74) + 0.70(1.00 + 0.99(14.74))
# 4.42 + 0.70(15.59)
# 15.33
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 15.33, 7.95]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.167701
# EXPLORATION
# Action Selected: Down
# Old Q-Value: 7.95
# Next Q-Value: 13.51
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(7.95) + 0.70(-1.00 + 0.99(13.51))
# 2.38 + 0.70(12.38)
# 11.05
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 15.33, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 13.51, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.771867
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 13.51
# Next Q-Value: 15.33
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(13.51) + 0.70(1.00 + 0.99(15.33))
# 4.05 + 0.70(16.18)
# 15.38
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 15.33, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.991150
# EXPLOITATION
# Action Selected: Up
# Old Q-Value: 15.33
# Next Q-Value: 15.33
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(15.33) + 0.70(1.00 + 0.99(15.33))
# 4.60 + 0.70(16.18)
# 15.93
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 15.93, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.076058
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 15.93
# Next Q-Value: 15.93
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(15.93) + 0.70(1.00 + 0.99(15.93))
# 4.78 + 0.70(16.77)
# 16.52
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [4.09, 10.09, 16.52, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.122057
# EXPLORATION
# Action Selected: Left
# Old Q-Value: 4.09
# Next Q-Value: 16.52
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(4.09) + 0.70(1.00 + 0.99(16.52))
# 1.23 + 0.70(17.35)
# 13.37
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [13.37, 10.09, 16.52, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.278954
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 16.52
# Next Q-Value: 16.52
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(16.52) + 0.70(1.00 + 0.99(16.52))
# 4.95 + 0.70(17.35)
# 17.10
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [13.37, 10.09, 17.10, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.234069
# EXPLORATION
# Action Selected: Left
# Old Q-Value: 13.37
# Next Q-Value: 17.10
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(13.37) + 0.70(1.00 + 0.99(17.10))
# 4.01 + 0.70(17.93)
# 16.56
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 10.09, 17.10, 11.05]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.033855
# EXPLORATION
# Action Selected: Down
# Old Q-Value: 11.05
# Next Q-Value: 15.38
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(11.05) + 0.70(-1.00 + 0.99(15.38))
# 3.31 + 0.70(14.23)
# 13.27
#
# STATE:
# |C| | |
# |L|B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 10.09, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 15.38, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.446057
# EXPLORATION
# Action Selected: Up
# Old Q-Value: 15.38
# Next Q-Value: 17.10
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(15.38) + 0.70(1.00 + 0.99(17.10))
# 4.61 + 0.70(17.93)
# 17.16
#
# STATE:
# |L| | |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 10.09, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.344850
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 10.09
# Next Q-Value: 14.34
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(10.09) + 0.70(-1.00 + 0.99(14.34))
# 3.03 + 0.70(13.20)
# 12.26
#
# STATE:
# |C|L| |
# | |B| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, 0.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.500000
# Random Sample: 0.414884
# EXPLORATION
# Action Selected: Down
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(-10.00 + 0.99(0.00))
# 0.00 + 0.70(-10.00)
# -7.00
#
# STATE:
# |C| | |
# | |L| |
# | | |W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.97, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -10
# Done: True
#
# =============
# EPISODE 6
# ==============
#
# ---------------
# Epsilon Threshold: 0.400000
# Random Sample: 0.534064
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: -0.97
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.97) + 0.70(-1.00 + 0.99(0.00))
# -0.29 + 0.70(-1.00)
# -0.99
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.99, -0.99, -1.75]
# 6: [-1.19, 0.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.400000
# Random Sample: 0.749541
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 0.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(0.00) + 0.70(10.00 + 0.99(0.00))
# 0.00 + 0.70(10.00)
# 7.00
#
# STATE:
# |C| | |
# | |B| |
# | | |L|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, -0.99, -0.99, -1.75]
# 6: [-1.19, 7.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 10
# Done: True
#
# =============
# EPISODE 7
# ==============
#
# ---------------
# Epsilon Threshold: 0.300000
# Random Sample: 0.343751
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: -0.99
# Next Q-Value: 7.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(-0.99) + 0.70(-1.00 + 0.99(7.00))
# -0.30 + 0.70(5.93)
# 3.85
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 3.85, -0.99, -1.75]
# 6: [-1.19, 7.00, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.300000
# Random Sample: 0.901502
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 7.00
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(7.00) + 0.70(10.00 + 0.99(0.00))
# 2.10 + 0.70(10.00)
# 9.10
#
# STATE:
# |C| | |
# | |B| |
# | | |L|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 3.85, -0.99, -1.75]
# 6: [-1.19, 9.10, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 10
# Done: True
#
# =============
# EPISODE 8
# ==============
#
# ---------------
# Epsilon Threshold: 0.200000
# Random Sample: 0.170881
# EXPLORATION
# Action Selected: Right
# Old Q-Value: 3.85
# Next Q-Value: 9.10
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(3.85) + 0.70(-1.00 + 0.99(9.10))
# 1.16 + 0.70(8.01)
# 6.76
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 6.76, -0.99, -1.75]
# 6: [-1.19, 9.10, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.200000
# Random Sample: 0.681533
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 9.10
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(9.10) + 0.70(10.00 + 0.99(0.00))
# 2.73 + 0.70(10.00)
# 9.73
#
# STATE:
# |C| | |
# | |B| |
# | | |L|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 6.76, -0.99, -1.75]
# 6: [-1.19, 9.73, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 10
# Done: True
#
# =============
# EPISODE 9
# ==============
#
# ---------------
# Epsilon Threshold: 0.100000
# Random Sample: 0.657383
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 6.76
# Next Q-Value: 9.73
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(6.76) + 0.70(-1.00 + 0.99(9.73))
# 2.03 + 0.70(8.63)
# 8.07
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 8.07, -0.99, -1.75]
# 6: [-1.19, 9.73, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.100000
# Random Sample: 0.946249
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 9.73
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(9.73) + 0.70(10.00 + 0.99(0.00))
# 2.92 + 0.70(10.00)
# 9.92
#
# STATE:
# |C| | |
# | |B| |
# | | |L|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 8.07, -0.99, -1.75]
# 6: [-1.19, 9.92, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 10
# Done: True
#
# =============
# EPISODE 10
# ==============
#
# ---------------
# Epsilon Threshold: 0.000000
# Random Sample: 0.186619
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 8.07
# Next Q-Value: 9.92
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(8.07) + 0.70(-1.00 + 0.99(9.92))
# 2.42 + 0.70(8.82)
# 8.60
#
# STATE:
# |C| | |
# | |B| |
# | |L|W|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 8.60, -0.99, -1.75]
# 6: [-1.19, 9.92, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: -1
# Done: False
#
# ---------------
# Epsilon Threshold: 0.000000
# Random Sample: 0.908147
# EXPLOITATION
# Action Selected: Right
# Old Q-Value: 9.92
# Next Q-Value: 0.00
# (1 - a)old_q + a(r + g(next_q)))
# (0.30)(9.92) + 0.70(10.00 + 0.99(0.00))
# 2.98 + 0.70(10.00)
# 9.98
#
# STATE:
# |C| | |
# | |B| |
# | | |L|
#
# Q Table:
#    [L, R, U, D]
# C: [16.56, 12.26, 17.10, 13.27]
# 1: [14.34, -0.70, 5.92, -7.00]
# 2: [5.61, 0.00, 0.00, 0.00]
# 3: [2.25, -9.73, 17.16, 0.00]
# B: [0.00, 0.00, 0.00, 0.00]
# 4: [0.00, 0.00, 0.00, 0.00]
# 5: [-1.60, 8.60, -0.99, -1.75]
# 6: [-1.19, 9.98, -9.10, 0.00]
# W: [0.00, 0.00, 0.00, 0.00]
#
# Reward: 10
# Done: True
#
# ===========
# FINAL STATS
# Rewards: [-11, -11, -14, -13, -11, 10, 9, 9, 9, 9, 9]
